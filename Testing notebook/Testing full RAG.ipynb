# %% [markdown]
# ### get some pdf and extract the text

# %%
file = "/content/drive/MyDrive/Unpacking fruit and veg - behavioural insights study.pdf"

# %%
# !pip install pdfminer.six -q

# %%
import pdfminer
from pdfminer.high_level import extract_text


def read_pdf(file):
    text = extract_text(file)
    return text

# %%
text = read_pdf(file)

# %%
text = text.replace("\n", "")

# %%
# !pip install spacy -q

# %%
from spacy.lang.en import English
import spacy

nlp = spacy.load('en_core_web_sm')

#text="Please read the analysis. This is another sentence"
doc = nlp(text)

# %%
for i in doc.sents:
  print(i)
  break
# Out:
# BEHAVIOURS,  ATTITUDES AND DEMANDUNPACKING FRESH UNPACKING FRESH FRUIT AND VEG:

# %% [markdown]
# ## Something like this will worl - writing about how tp extract text and garbage in garbage out etc.
